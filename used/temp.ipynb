# %%
import requests
import re
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
base_url = "https://krisha.kz"
search_url = "https://krisha.kz/prodazha/kvartiry/almaty/"

# Initialize a list to store apartment links
apartment_links = []

# Assuming a maximum of 100 pages, adjust as needed
for page_num in range(1, 100):
    # Append the current page number to the search URL
    current_page_url = f"{search_url}?page={page_num}"

    # Send request and parse the page
    response = requests.get(current_page_url)
    time.sleep(1)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Check if the page has any listings
    listings = soup.find_all("a", class_="a-card__title")
    if not listings:
        break  # No more listings, exit the loop

    # Extract and store the links
    for link in listings:
        apartment_links.append(base_url + link.get('href'))

# Print the total number of links found
print(f"Found {len(apartment_links)} apartment links.")

with open('links.csv', 'a', newline='', encoding='utf-8') as csvfile:
    csv_writer = csv.writer(csvfile)
    for apartment_link in apartment_links:
        csv_writer.writerow(apartment_link)
# Out:
# Found 22 apartment links.

# %%
def get_apartment_data(url):
    response = requests.get(url)
    time.sleep(1)
    soup = BeautifulSoup(response.text, 'html.parser')

    # Extracting room count
    title_text = soup.find("div", class_="offer__advert-title").find("h1").text
    room_count_match = re.search(r'(\d+)-комнатная', title_text)
    room_count = int(room_count_match.group(1)) if room_count_match else None

    # Extracting quadrature
    try:
        quadrature = float(title_text.split(',')[1].split()[0])
    except IndexError:
        print("Index out of bound for quadrature")

    # Extracting floor
    floor_div = soup.find("div", {"data-name": "flat.floor"})
    if floor_div is not None:
        floor_info_text = floor_div.find("div", class_="offer__advert-short-info").text
        floor_info = floor_info_text.split('из')
        try:
            floor_text = floor_info[0].strip()+"/"+floor_info[-1].strip()
        except IndexError:
            print("Index out of bound for floor_text")
        floor = round(float(floor_info[0].strip()) / float(floor_info[-1].strip()), 2)
    else:
        floor_text = '1/1'
        floor = 1
        
    # Extracting region
    try:
        region_text = soup.find("div", class_="offer__location offer__advert-short-info").find("span").text.split(',')[-1].strip()
        # print(region_text)
    except IndexError:
        print("Index out of bound for region_text")
        
    if region_text == 'Алатауский р-н':
        region = 1e-10
    elif region_text == 'Алмалинский р-н':
        region = 0.075
    elif region_text == 'Ауэзовский р-н':
        region = 0.51
    elif region_text == 'Бостандыкский р-н':
        region = 1
    elif region_text == 'Жетысуский р-н':
        region = 0.076
    elif region_text == 'Медеуский р-н':
        region = 0.69
    elif region_text == 'Наурызбайский р-н':
        region = 0.11
    elif region_text == 'Турксибский р-н':
        region = 0.083
    elif region_text == 'Алматы':
        region = None

    # Extracting year
    year_div = soup.find("div", {"data-name": "house.year"})
    year_text = year_div.find("div", class_="offer__advert-short-info").text
    year = int(''.join(filter(str.isdigit, year_text)))

    # Extracting price
    
    price_text = soup.find(class_='offer__price').text
    price = int("".join(filter(str.isdigit, price_text)))

    # Extracting about
    about_dict = {}

    apartmentAbout = soup.find("div", class_="offer__parameters")

    if len(apartmentAbout) != 1:
        desired_data_names = ['flat.toilet', 'flat.balcony', 'flat.balcony_g', 'flat.door', 'inet.type', 'flat.parking',
                              'live.furniture', 'flat.flooring']

        for desired_data_name in desired_data_names:
            # Find the dt element with the specified data-name
            dt_element = apartmentAbout.find('dt', {"data-name": desired_data_name})

            about_name = desired_data_name.replace('.', '_')
            # print(about_name)
            # If the dt element is found, extract the dd value
            if dt_element:
                dd_element = dt_element.find_next_sibling("dd")
                if dd_element:
                    about_dict[about_name] = dd_element.get_text().strip()
                    # print(dd_element.get_text().strip())
            else:
                about_dict[about_name] = 'no_info'

    # Extracting ceiling
    dt_element = apartmentAbout.find('dt', {"data-name": 'ceiling'})

    if dt_element:
        dd_element = dt_element.find_next_sibling("dd")
        if dd_element:
            try:
                about_dict['ceiling'] = dd_element.get_text().strip().split()[0]
            except IndexError:
                print("Index out of bound for dd_element")
    else:
        about_dict['ceiling'] = None
        
    # Extracting flat.priv_dorm
    dt_element = apartmentAbout.find('dt', {"data-name": 'flat.priv_dorm'})

    if dt_element:
        dd_element = dt_element.find_next_sibling("dd")
        if dd_element:
            if dd_element.get_text().strip() == 'да':
                about_dict['flat_priv_dorm'] = 1
            else:
                about_dict['flat_priv_dorm'] = 0
    else:
        about_dict['flat_priv_dorm'] = 0

    total_dict = {"price": price,
                  "room_count": room_count,
                  "quadrature": quadrature,
                  "floor_text": floor_text,
                  "floor": floor,
                  "region_text": region_text,
                  "region": region,
                  "year": year}
    total_dict.update(about_dict)
    # print(total_dict)
    return total_dict

# %%
data = []

df = pd.read_csv('last_links_of_ap.csv')
links = df.iloc[:, 0].values
i=0
for link in links[10000:11000]:
    try:
        print(i, link)
        apartment_data = get_apartment_data(link)
        data.append(apartment_data)
        i+=1
    except Exception as e:
        print(f"Failed to extract data from {link}. Error: {e}")
# Out:
# 0 https://krisha.kz/a/show/687747727
# 1 https://krisha.kz/a/show/688970880
# 2 https://krisha.kz/a/show/689000294
# 3 https://krisha.kz/a/show/688999649
# 4 https://krisha.kz/a/show/688171507
# 5 https://krisha.kz/a/show/689001087
# 6 https://krisha.kz/a/show/686661136
# 7 https://krisha.kz/a/show/689001765
# 8 https://krisha.kz/a/show/688768024
# 9 https://krisha.kz/a/show/685944682
# 10 https://krisha.kz/a/show/688842658
# 11 https://krisha.kz/a/show/685254807
# 12 https://krisha.kz/a/show/687344773
# 13 https://krisha.kz/a/show/688102368
# 14 https://krisha.kz/a/show/687879883
# 15 https://krisha.kz/a/show/685316463
# 16 https://krisha.kz/a/show/688690309
# 17 https://krisha.kz/a/show/683986051
# 18 https://krisha.kz/a/show/688227691
# 19 https://krisha.kz/a/show/688845238
# 20 https://krisha.kz/a/show/688568852
# 21 https://krisha.kz/a/show/686593369
# 22 https://krisha.kz/a/show/688758859
# 23 https://krisha.kz/a/show/688933749
# 24 https://krisha.kz/a/show/684760495
# 25 https://krisha.kz/a/show/686972239
# 26 https://krisha.kz/a/show/688471100
# 27 https://krisha.kz/a/show/688315446
# 28 https://krisha.kz/a/show/688896508
# 29 https://krisha.kz/a/show/688879378
# 30 https://krisha.kz/a/show/688879429
# 31 https://krisha.kz/a/show/688792884
# 32 https://krisha.kz/a/show/688957955
# 33 https://krisha.kz/a/show/688596886
# 34 https://krisha.kz/a/show/688901024
# 35 https://krisha.kz/a/show/688901187
# 36 https://krisha.kz/a/show/688597154
# 37 https://krisha.kz/a/show/688809806
# 38 https://krisha.kz/a/show/688524892
# 39 https://krisha.kz/a/show/683872708
# 40 https://krisha.kz/a/show/687588347
# 41 https://krisha.kz/a/show/688998463
# 42 https://krisha.kz/a/show/688477262
# 43 https://krisha.kz/a/show/688847271
# 44 https://krisha.kz/a/show/688302136
# 45 https://krisha.kz/a/show/685873776
# 46 https://krisha.kz/a/show/688844565
# 47 https://krisha.kz/a/show/688876752
# 48 https://krisha.kz/a/show/683215528
# 49 https://krisha.kz/a/show/683806614
# 50 https://krisha.kz/a/show/688766030
# 51 https://krisha.kz/a/show/688735602
# 52 https://krisha.kz/a/show/676365381
# 53 https://krisha.kz/a/show/680469626
# 54 https://krisha.kz/a/show/683194856
# 55 https://krisha.kz/a/show/688918529
# 56 https://krisha.kz/a/show/687330077
# 57 https://krisha.kz/a/show/688330429
# 58 https://krisha.kz/a/show/688183520
# 59 https://krisha.kz/a/show/666845224
# 60 https://krisha.kz/a/show/688483747
# 61 https://krisha.kz/a/show/683531939
# 62 https://krisha.kz/a/show/688808955
# 63 https://krisha.kz/a/show/687604377
# 64 https://krisha.kz/a/show/683580247
# 65 https://krisha.kz/a/show/683210298
# 66 https://krisha.kz/a/show/688957507
# 67 https://krisha.kz/a/show/687698415
# 68 https://krisha.kz/a/show/686937489
# 69 https://krisha.kz/a/show/688948295
# 70 https://krisha.kz/a/show/684842912
# 71 https://krisha.kz/a/show/683206918
# 72 https://krisha.kz/a/show/683512636
# 73 https://krisha.kz/a/show/685447753
# 74 https://krisha.kz/a/show/686573032
# 75 https://krisha.kz/a/show/686572121
# 76 https://krisha.kz/a/show/688766455
# 77 https://krisha.kz/a/show/678942135
# 78 https://krisha.kz/a/show/663346436
# 79 https://krisha.kz/a/show/688972269
# 80 https://krisha.kz/a/show/688846259
# 81 https://krisha.kz/a/show/682650385
# 82 https://krisha.kz/a/show/688285822
# 83 https://krisha.kz/a/show/688623661
# 84 https://krisha.kz/a/show/678392937
# 85 https://krisha.kz/a/show/688607855
# 86 https://krisha.kz/a/show/683693286
# 87 https://krisha.kz/a/show/687771158
# 88 https://krisha.kz/a/show/688219565
# 89 https://krisha.kz/a/show/688041526
# 90 https://krisha.kz/a/show/688589900
# 91 https://krisha.kz/a/show/688967316
# 92 https://krisha.kz/a/show/688999913
# 93 https://krisha.kz/a/show/688724098
# 94 https://krisha.kz/a/show/688164381
# 95 https://krisha.kz/a/show/687799472
# 96 https://krisha.kz/a/show/688517717
# 97 https://krisha.kz/a/show/679703600
# 98 https://krisha.kz/a/show/671121626
# 99 https://krisha.kz/a/show/688256781
# 100 https://krisha.kz/a/show/671976173
# 101 https://krisha.kz/a/show/55691196
# 102 https://krisha.kz/a/show/688001058
# 103 https://krisha.kz/a/show/684483087
# 104 https://krisha.kz/a/show/686818034
# 105 https://krisha.kz/a/show/688926062
# 106 https://krisha.kz/a/show/688010784
# 107 https://krisha.kz/a/show/688932026
# 108 https://krisha.kz/a/show/687684505
# 109 https://krisha.kz/a/show/688337191
# 110 https://krisha.kz/a/show/687900695
# 111 https://krisha.kz/a/show/688917927
# 112 https://krisha.kz/a/show/685310048
# 113 https://krisha.kz/a/show/688957502
# 114 https://krisha.kz/a/show/688961048
# 115 https://krisha.kz/a/show/688961210
# 116 https://krisha.kz/a/show/688946942
# 117 https://krisha.kz/a/show/687435796
# 118 https://krisha.kz/a/show/688971350
# 119 https://krisha.kz/a/show/688083764
# 120 https://krisha.kz/a/show/688888375
# 121 https://krisha.kz/a/show/685768911
# 122 https://krisha.kz/a/show/687979839
# 123 https://krisha.kz/a/show/688314444
# 124 https://krisha.kz/a/show/688779620
# 125 https://krisha.kz/a/show/686794837
# 126 https://krisha.kz/a/show/688366490
# 127 https://krisha.kz/a/show/673478718
# 128 https://krisha.kz/a/show/689001952
# 129 https://krisha.kz/a/show/688841458
# 130 https://krisha.kz/a/show/688712130
# 131 https://krisha.kz/a/show/687843691
# 132 https://krisha.kz/a/show/673130682
# 133 https://krisha.kz/a/show/688097656
# 134 https://krisha.kz/a/show/688108219
# 135 https://krisha.kz/a/show/682890521
# 136 https://krisha.kz/a/show/683272563
# 137 https://krisha.kz/a/show/688869196
# 138 https://krisha.kz/a/show/688837820
# 139 https://krisha.kz/a/show/688979165
# 140 https://krisha.kz/a/show/686817266
# 141 https://krisha.kz/a/show/688664269
# 142 https://krisha.kz/a/show/688972831
# 143 https://krisha.kz/a/show/687670431
# 144 https://krisha.kz/a/show/688485486
# 145 https://krisha.kz/a/show/688844580
# 146 https://krisha.kz/a/show/686803414
# 147 https://krisha.kz/a/show/688484047
# 148 https://krisha.kz/a/show/686376554
# 149 https://krisha.kz/a/show/688894483
# 150 https://krisha.kz/a/show/677613509
# 151 https://krisha.kz/a/show/688756051
# 152 https://krisha.kz/a/show/687072969
# 153 https://krisha.kz/a/show/687617494
# 154 https://krisha.kz/a/show/688426043
# 155 https://krisha.kz/a/show/688032877
# 156 https://krisha.kz/a/show/688933791
# 157 https://krisha.kz/a/show/688917852
# 158 https://krisha.kz/a/show/677874308
# 159 https://krisha.kz/a/show/688962664
# 160 https://krisha.kz/a/show/688951691
# 161 https://krisha.kz/a/show/687171149
# 162 https://krisha.kz/a/show/685807639
# 163 https://krisha.kz/a/show/688979158
# 164 https://krisha.kz/a/show/688979016
# 165 https://krisha.kz/a/show/688979215
# 166 https://krisha.kz/a/show/688993578
# 167 https://krisha.kz/a/show/688999772
# 168 https://krisha.kz/a/show/676872622
# 169 https://krisha.kz/a/show/687719035
# 170 https://krisha.kz/a/show/683560541
# 171 https://krisha.kz/a/show/688938405
# 172 https://krisha.kz/a/show/688839754
# 173 https://krisha.kz/a/show/683215365
# 174 https://krisha.kz/a/show/683711180
# 175 https://krisha.kz/a/show/680247146
# 176 https://krisha.kz/a/show/688870929
# 177 https://krisha.kz/a/show/688503339
# 178 https://krisha.kz/a/show/688353258
# 179 https://krisha.kz/a/show/684678698
# 180 https://krisha.kz/a/show/687838593
# 181 https://krisha.kz/a/show/688846776
# 182 https://krisha.kz/a/show/688844572
# 183 https://krisha.kz/a/show/688350627
# 184 https://krisha.kz/a/show/687210881
# 185 https://krisha.kz/a/show/677391013
# 186 https://krisha.kz/a/show/687623244
# 187 https://krisha.kz/a/show/688736501
# 188 https://krisha.kz/a/show/686313636
# 189 https://krisha.kz/a/show/687757936
# 190 https://krisha.kz/a/show/688175327
# 191 https://krisha.kz/a/show/686762218
# 192 https://krisha.kz/a/show/688883246
# 193 https://krisha.kz/a/show/688885880
# 194 https://krisha.kz/a/show/688222943
# 195 https://krisha.kz/a/show/688853351
# 196 https://krisha.kz/a/show/688749019
# 197 https://krisha.kz/a/show/687263828
# 198 https://krisha.kz/a/show/688933888
# 199 https://krisha.kz/a/show/688434985
# 200 https://krisha.kz/a/show/685799960
# 201 https://krisha.kz/a/show/688915335
# 202 https://krisha.kz/a/show/688131764
# 203 https://krisha.kz/a/show/687980833
# 204 https://krisha.kz/a/show/682447280
# 205 https://krisha.kz/a/show/685115459
# 206 https://krisha.kz/a/show/682626409
# 207 https://krisha.kz/a/show/688960633
# 208 https://krisha.kz/a/show/682895383
# 209 https://krisha.kz/a/show/688958047
# 210 https://krisha.kz/a/show/687471074
# 211 https://krisha.kz/a/show/687364445
# 212 https://krisha.kz/a/show/688545723
# 213 https://krisha.kz/a/show/688299953
# 214 https://krisha.kz/a/show/688863567
# 215 https://krisha.kz/a/show/688800566
# 216 https://krisha.kz/a/show/688865747
# 217 https://krisha.kz/a/show/688943684
# 218 https://krisha.kz/a/show/688930859
# 219 https://krisha.kz/a/show/686400702
# 220 https://krisha.kz/a/show/688985239
# 221 https://krisha.kz/a/show/686867231
# 222 https://krisha.kz/a/show/688251957
# 223 https://krisha.kz/a/show/688142499
# 224 https://krisha.kz/a/show/688702483
# 225 https://krisha.kz/a/show/688716271
# 226 https://krisha.kz/a/show/688663793
# 227 https://krisha.kz/a/show/687952957
# 228 https://krisha.kz/a/show/687756093
# 229 https://krisha.kz/a/show/683304272
# 230 https://krisha.kz/a/show/688995381
# 231 https://krisha.kz/a/show/685926183
# 232 https://krisha.kz/a/show/688569633
# 233 https://krisha.kz/a/show/687215492
# 234 https://krisha.kz/a/show/688999342
# 235 https://krisha.kz/a/show/689000626
# 236 https://krisha.kz/a/show/685766541
# 237 https://krisha.kz/a/show/688649688
# 238 https://krisha.kz/a/show/688355548
# 239 https://krisha.kz/a/show/688626455
# 240 https://krisha.kz/a/show/681798814
# 241 https://krisha.kz/a/show/685831628
# 242 https://krisha.kz/a/show/683292883
# 243 https://krisha.kz/a/show/684579281
# 244 https://krisha.kz/a/show/684777888
# 245 https://krisha.kz/a/show/688009913
# 246 https://krisha.kz/a/show/687412149
# 247 https://krisha.kz/a/show/681912062
# 248 https://krisha.kz/a/show/688725376
# 249 https://krisha.kz/a/show/21040224
# 250 https://krisha.kz/a/show/684397818
# 251 https://krisha.kz/a/show/686322644
# 252 https://krisha.kz/a/show/682419029
# 253 https://krisha.kz/a/show/680182718
# 254 https://krisha.kz/a/show/669463343
# 255 https://krisha.kz/a/show/688906329
# 256 https://krisha.kz/a/show/687740620
# 257 https://krisha.kz/a/show/688931597
# 258 https://krisha.kz/a/show/688237156
# 259 https://krisha.kz/a/show/688918437
# 260 https://krisha.kz/a/show/688926179
# 261 https://krisha.kz/a/show/688926293
# 262 https://krisha.kz/a/show/688596094
# 263 https://krisha.kz/a/show/688913042
# 264 https://krisha.kz/a/show/686762104
# 265 https://krisha.kz/a/show/685734990
# 266 https://krisha.kz/a/show/688941916
# 267 https://krisha.kz/a/show/687028317
# 268 https://krisha.kz/a/show/688985297
# 269 https://krisha.kz/a/show/676546582
# 270 https://krisha.kz/a/show/685134353
# 271 https://krisha.kz/a/show/688956804
# 272 https://krisha.kz/a/show/688975572
# 273 https://krisha.kz/a/show/688952063
# 274 https://krisha.kz/a/show/677864761
# 275 https://krisha.kz/a/show/688880286
# 276 https://krisha.kz/a/show/688794812
# 277 https://krisha.kz/a/show/688921435
# 278 https://krisha.kz/a/show/688049047
# 279 https://krisha.kz/a/show/683929054
# 280 https://krisha.kz/a/show/688388900
# 281 https://krisha.kz/a/show/688181625
# 282 https://krisha.kz/a/show/688638240
# 283 https://krisha.kz/a/show/686444003
# 284 https://krisha.kz/a/show/688664246
# 285 https://krisha.kz/a/show/688865209
# 286 https://krisha.kz/a/show/681300259
# 287 https://krisha.kz/a/show/684622902
# 288 https://krisha.kz/a/show/688950958
# 289 https://krisha.kz/a/show/688971228
# 290 https://krisha.kz/a/show/688997989
# 291 https://krisha.kz/a/show/688998979
# 292 https://krisha.kz/a/show/688910786
# 293 https://krisha.kz/a/show/683107362
# 294 https://krisha.kz/a/show/682932223
# 295 https://krisha.kz/a/show/686078872
# 296 https://krisha.kz/a/show/687671667
# 297 https://krisha.kz/a/show/672016460
# 298 https://krisha.kz/a/show/688868965
# 299 https://krisha.kz/a/show/682626200
# 300 https://krisha.kz/a/show/687853127
# 301 https://krisha.kz/a/show/688878550
# 302 https://krisha.kz/a/show/27235745
# 303 https://krisha.kz/a/show/683898889
# 304 https://krisha.kz/a/show/688912502
# Failed to extract data from https://krisha.kz/a/show/688912502. Error: 'NoneType' object has no attribute 'find'
# 304 https://krisha.kz/a/show/681876692
# 305 https://krisha.kz/a/show/686807762
# 306 https://krisha.kz/a/show/686713423
# 307 https://krisha.kz/a/show/685870573
# 308 https://krisha.kz/a/show/58501032
# 309 https://krisha.kz/a/show/685832002
# 310 https://krisha.kz/a/show/682767855
# 311 https://krisha.kz/a/show/688883502
# 312 https://krisha.kz/a/show/684759207
# 313 https://krisha.kz/a/show/688697361
# 314 https://krisha.kz/a/show/688925300
# 315 https://krisha.kz/a/show/688926456
# 316 https://krisha.kz/a/show/688158101
# 317 https://krisha.kz/a/show/686429899
# 318 https://krisha.kz/a/show/688926535
# 319 https://krisha.kz/a/show/688027335
# 320 https://krisha.kz/a/show/687553736
# 321 https://krisha.kz/a/show/688764586
# 322 https://krisha.kz/a/show/688943082
# 323 https://krisha.kz/a/show/688788795
# 324 https://krisha.kz/a/show/688965550
# 325 https://krisha.kz/a/show/688752873
# 326 https://krisha.kz/a/show/688914166
# 327 https://krisha.kz/a/show/678936147
# 328 https://krisha.kz/a/show/688949846
# 329 https://krisha.kz/a/show/688958907
# 330 https://krisha.kz/a/show/688932640
# 331 https://krisha.kz/a/show/688948867
# 332 https://krisha.kz/a/show/685831881
# 333 https://krisha.kz/a/show/688978253
# 334 https://krisha.kz/a/show/686682134
# 335 https://krisha.kz/a/show/688668250
# 336 https://krisha.kz/a/show/688981726
# 337 https://krisha.kz/a/show/688956387
# 338 https://krisha.kz/a/show/687203901
# 339 https://krisha.kz/a/show/688798147
# 340 https://krisha.kz/a/show/687527657
# 341 https://krisha.kz/a/show/688327199
# 342 https://krisha.kz/a/show/687769442
# 343 https://krisha.kz/a/show/688039470
# 344 https://krisha.kz/a/show/688842105
# 345 https://krisha.kz/a/show/688353778
# 346 https://krisha.kz/a/show/686563711
# 347 https://krisha.kz/a/show/688944646
# 348 https://krisha.kz/a/show/688996012
# 349 https://krisha.kz/a/show/688587755
# 350 https://krisha.kz/a/show/688972215
# 351 https://krisha.kz/a/show/687068013
# 352 https://krisha.kz/a/show/688100958
# 353 https://krisha.kz/a/show/686711209
# 354 https://krisha.kz/a/show/687833090
# 355 https://krisha.kz/a/show/684863910
# 356 https://krisha.kz/a/show/688931435
# 357 https://krisha.kz/a/show/688928776
# 358 https://krisha.kz/a/show/688921398
# 359 https://krisha.kz/a/show/688278314
# 360 https://krisha.kz/a/show/675290967
# 361 https://krisha.kz/a/show/687758968
# 362 https://krisha.kz/a/show/687767108
# 363 https://krisha.kz/a/show/688726387
# 364 https://krisha.kz/a/show/688492421
# 365 https://krisha.kz/a/show/688765747
# 366 https://krisha.kz/a/show/687465890
# 367 https://krisha.kz/a/show/688490651
# 368 https://krisha.kz/a/show/685626004
# 369 https://krisha.kz/a/show/680096009
# 370 https://krisha.kz/a/show/683088000
# 371 https://krisha.kz/a/show/686096192
# 372 https://krisha.kz/a/show/688603880
# 373 https://krisha.kz/a/show/664331816
# 374 https://krisha.kz/a/show/688554232
# 375 https://krisha.kz/a/show/684482097
# 376 https://krisha.kz/a/show/688509022
# 377 https://krisha.kz/a/show/683560658
# 378 https://krisha.kz/a/show/688127837
# 379 https://krisha.kz/a/show/688844121
# 380 https://krisha.kz/a/show/684863719
# 381 https://krisha.kz/a/show/688475900
# 382 https://krisha.kz/a/show/687983789
# 383 https://krisha.kz/a/show/684354905
# 384 https://krisha.kz/a/show/688661066
# 385 https://krisha.kz/a/show/688486117
# 386 https://krisha.kz/a/show/688855186
# 387 https://krisha.kz/a/show/685857547
# 388 https://krisha.kz/a/show/688841313
# 389 https://krisha.kz/a/show/687775868
# 390 https://krisha.kz/a/show/686445774
# 391 https://krisha.kz/a/show/688679481
# 392 https://krisha.kz/a/show/688759099
# 393 https://krisha.kz/a/show/688882797
# 394 https://krisha.kz/a/show/688858282
# 395 https://krisha.kz/a/show/688314755
# 396 https://krisha.kz/a/show/688403689
# 397 https://krisha.kz/a/show/686718855
# 398 https://krisha.kz/a/show/687960223
# 399 https://krisha.kz/a/show/686985698
# 400 https://krisha.kz/a/show/688126116
# 401 https://krisha.kz/a/show/688863908
# 402 https://krisha.kz/a/show/683088126
# 403 https://krisha.kz/a/show/687648398
# 404 https://krisha.kz/a/show/688985855
# 405 https://krisha.kz/a/show/672477613
# 406 https://krisha.kz/a/show/688822435
# 407 https://krisha.kz/a/show/688577956
# 408 https://krisha.kz/a/show/685612789
# 409 https://krisha.kz/a/show/687819559
# 410 https://krisha.kz/a/show/689001629
# 411 https://krisha.kz/a/show/688858429
# 412 https://krisha.kz/a/show/688760020
# 413 https://krisha.kz/a/show/688861227
# 414 https://krisha.kz/a/show/688862287
# 415 https://krisha.kz/a/show/688864948
# 416 https://krisha.kz/a/show/688866058
# 417 https://krisha.kz/a/show/688880506
# 418 https://krisha.kz/a/show/688881617
# 419 https://krisha.kz/a/show/688883110
# 420 https://krisha.kz/a/show/688946276
# 421 https://krisha.kz/a/show/688631815
# 422 https://krisha.kz/a/show/688929705
# 423 https://krisha.kz/a/show/688933063
# 424 https://krisha.kz/a/show/688773335
# 425 https://krisha.kz/a/show/681330937
# 426 https://krisha.kz/a/show/688240175
# 427 https://krisha.kz/a/show/688945004
# 428 https://krisha.kz/a/show/675835230
# 429 https://krisha.kz/a/show/688967184
# 430 https://krisha.kz/a/show/688979334
# 431 https://krisha.kz/a/show/688954063
# 432 https://krisha.kz/a/show/688861883
# 433 https://krisha.kz/a/show/688972088
# 434 https://krisha.kz/a/show/686718382
# 435 https://krisha.kz/a/show/688378566
# 436 https://krisha.kz/a/show/688538882
# 437 https://krisha.kz/a/show/683615076
# 438 https://krisha.kz/a/show/688998427
# 439 https://krisha.kz/a/show/688873660
# 440 https://krisha.kz/a/show/685304777
# 441 https://krisha.kz/a/show/688865542
# 442 https://krisha.kz/a/show/686902106
# 443 https://krisha.kz/a/show/686084925
# 444 https://krisha.kz/a/show/688260247
# 445 https://krisha.kz/a/show/688730086
# 446 https://krisha.kz/a/show/688919423
# 447 https://krisha.kz/a/show/688795270
# 448 https://krisha.kz/a/show/688927916
# 449 https://krisha.kz/a/show/688669683
# 450 https://krisha.kz/a/show/688669711
# 451 https://krisha.kz/a/show/682723538
# 452 https://krisha.kz/a/show/688429456
# 453 https://krisha.kz/a/show/685615508
# 454 https://krisha.kz/a/show/688951786
# 455 https://krisha.kz/a/show/688864114
# 456 https://krisha.kz/a/show/688492887
# 457 https://krisha.kz/a/show/688818618
# 458 https://krisha.kz/a/show/675930649
# 459 https://krisha.kz/a/show/679981525
# 460 https://krisha.kz/a/show/688345104
# 461 https://krisha.kz/a/show/688902918
# 462 https://krisha.kz/a/show/683297832
# 463 https://krisha.kz/a/show/688843927
# 464 https://krisha.kz/a/show/688848323
# 465 https://krisha.kz/a/show/688862307
# 466 https://krisha.kz/a/show/684102169
# 467 https://krisha.kz/a/show/684571165
# 468 https://krisha.kz/a/show/682690435
# 469 https://krisha.kz/a/show/688979791
# 470 https://krisha.kz/a/show/687799559
# 471 https://krisha.kz/a/show/683675899
# 472 https://krisha.kz/a/show/688700701
# 473 https://krisha.kz/a/show/687804544
# 474 https://krisha.kz/a/show/687758445
# 475 https://krisha.kz/a/show/687758799
# 476 https://krisha.kz/a/show/687767065
# 477 https://krisha.kz/a/show/687758512
# 478 https://krisha.kz/a/show/685241570
# 479 https://krisha.kz/a/show/688705213
# 480 https://krisha.kz/a/show/688004008
# 481 https://krisha.kz/a/show/682222957
# 482 https://krisha.kz/a/show/688511946
# 483 https://krisha.kz/a/show/688005581
# 484 https://krisha.kz/a/show/686567876
# 485 https://krisha.kz/a/show/683844998
# 486 https://krisha.kz/a/show/684959794
# 487 https://krisha.kz/a/show/688891018
# 488 https://krisha.kz/a/show/688893218
# 489 https://krisha.kz/a/show/688529419
# 490 https://krisha.kz/a/show/687893564
# 491 https://krisha.kz/a/show/688731990
# 492 https://krisha.kz/a/show/688714630
# 493 https://krisha.kz/a/show/682412909
# 494 https://krisha.kz/a/show/681704471
# 495 https://krisha.kz/a/show/687021566
# 496 https://krisha.kz/a/show/688346421
# 497 https://krisha.kz/a/show/685048897
# 498 https://krisha.kz/a/show/688626326
# 499 https://krisha.kz/a/show/688352083
# 500 https://krisha.kz/a/show/688760601
# 501 https://krisha.kz/a/show/687379763
# 502 https://krisha.kz/a/show/687921894
# 503 https://krisha.kz/a/show/688606407
# 504 https://krisha.kz/a/show/688973766
# 505 https://krisha.kz/a/show/688973805
# 506 https://krisha.kz/a/show/688912446
# 507 https://krisha.kz/a/show/688756536
# 508 https://krisha.kz/a/show/688759008
# 509 https://krisha.kz/a/show/685649089
# 510 https://krisha.kz/a/show/688921780
# 511 https://krisha.kz/a/show/688567519
# 512 https://krisha.kz/a/show/683894312
# 513 https://krisha.kz/a/show/687922847
# 514 https://krisha.kz/a/show/688946239
# 515 https://krisha.kz/a/show/686566148
# 516 https://krisha.kz/a/show/688633107
# 517 https://krisha.kz/a/show/688811996
# 518 https://krisha.kz/a/show/688002138
# 519 https://krisha.kz/a/show/688254020
# 520 https://krisha.kz/a/show/688951709
# 521 https://krisha.kz/a/show/688584365
# 522 https://krisha.kz/a/show/688981216
# 523 https://krisha.kz/a/show/688889131
# 524 https://krisha.kz/a/show/685762125
# 525 https://krisha.kz/a/show/688309142
# 526 https://krisha.kz/a/show/688984636
# 527 https://krisha.kz/a/show/688984819
# 528 https://krisha.kz/a/show/677113948
# 529 https://krisha.kz/a/show/688984556
# 530 https://krisha.kz/a/show/688989334
# 531 https://krisha.kz/a/show/688531088
# 532 https://krisha.kz/a/show/687045622
# 533 https://krisha.kz/a/show/682503643
# 534 https://krisha.kz/a/show/683322351
# 535 https://krisha.kz/a/show/685082862
# 536 https://krisha.kz/a/show/681868456
# 537 https://krisha.kz/a/show/688756285
# 538 https://krisha.kz/a/show/688687262
# 539 https://krisha.kz/a/show/688996859
# 540 https://krisha.kz/a/show/688822798
# 541 https://krisha.kz/a/show/688990822
# 542 https://krisha.kz/a/show/688686664
# 543 https://krisha.kz/a/show/672417445
# 544 https://krisha.kz/a/show/674637611
# 545 https://krisha.kz/a/show/676476553
# 546 https://krisha.kz/a/show/676784362
# 547 https://krisha.kz/a/show/688819153
# 548 https://krisha.kz/a/show/688178369
# 549 https://krisha.kz/a/show/688339961
# 550 https://krisha.kz/a/show/688516560
# 551 https://krisha.kz/a/show/688159544
# 552 https://krisha.kz/a/show/673289669
# 553 https://krisha.kz/a/show/683381711
# 554 https://krisha.kz/a/show/684191986
# 555 https://krisha.kz/a/show/684644613
# 556 https://krisha.kz/a/show/683503127
# 557 https://krisha.kz/a/show/688486697
# 558 https://krisha.kz/a/show/688865622
# 559 https://krisha.kz/a/show/686674457
# 560 https://krisha.kz/a/show/688217315
# 561 https://krisha.kz/a/show/676756554
# 562 https://krisha.kz/a/show/677161476
# 563 https://krisha.kz/a/show/688856172
# 564 https://krisha.kz/a/show/686500040
# 565 https://krisha.kz/a/show/688385631
# 566 https://krisha.kz/a/show/685269804
# 567 https://krisha.kz/a/show/677751105
# 568 https://krisha.kz/a/show/688401186
# 569 https://krisha.kz/a/show/688573741
# 570 https://krisha.kz/a/show/686026743
# 571 https://krisha.kz/a/show/682652143
# 572 https://krisha.kz/a/show/678405860
# 573 https://krisha.kz/a/show/685379702
# 574 https://krisha.kz/a/show/688548882
# 575 https://krisha.kz/a/show/688925421
# 576 https://krisha.kz/a/show/688248575
# 577 https://krisha.kz/a/show/688928326
# 578 https://krisha.kz/a/show/688844722
# 579 https://krisha.kz/a/show/688843195
# 580 https://krisha.kz/a/show/688883346
# 581 https://krisha.kz/a/show/688519522
# 582 https://krisha.kz/a/show/681365663
# 583 https://krisha.kz/a/show/688411937
# 584 https://krisha.kz/a/show/685109319
# 585 https://krisha.kz/a/show/688429592
# 586 https://krisha.kz/a/show/688938518
# 587 https://krisha.kz/a/show/688266512
# 588 https://krisha.kz/a/show/688958302
# 589 https://krisha.kz/a/show/688956962
# 590 https://krisha.kz/a/show/688955919
# 591 https://krisha.kz/a/show/685197826
# 592 https://krisha.kz/a/show/686513266
# 593 https://krisha.kz/a/show/687946042
# 594 https://krisha.kz/a/show/688129809
# 595 https://krisha.kz/a/show/688942708
# 596 https://krisha.kz/a/show/686956715
# 597 https://krisha.kz/a/show/688945338
# 598 https://krisha.kz/a/show/684901680
# 599 https://krisha.kz/a/show/688967160
# 600 https://krisha.kz/a/show/687949920
# 601 https://krisha.kz/a/show/682710094
# 602 https://krisha.kz/a/show/688932462
# 603 https://krisha.kz/a/show/688947274
# 604 https://krisha.kz/a/show/688944922
# 605 https://krisha.kz/a/show/688952975
# 606 https://krisha.kz/a/show/688949524
# 607 https://krisha.kz/a/show/688783893
# 608 https://krisha.kz/a/show/688949646
# 609 https://krisha.kz/a/show/688785257
# 610 https://krisha.kz/a/show/688396471
# 611 https://krisha.kz/a/show/687948730
# 612 https://krisha.kz/a/show/688613696
# 613 https://krisha.kz/a/show/688484131
# 614 https://krisha.kz/a/show/688842532
# 615 https://krisha.kz/a/show/686097940
# 616 https://krisha.kz/a/show/688995125
# 617 https://krisha.kz/a/show/683316718
# 618 https://krisha.kz/a/show/688974157
# 619 https://krisha.kz/a/show/688662021
# 620 https://krisha.kz/a/show/688332826
# 621 https://krisha.kz/a/show/686188997
# 622 https://krisha.kz/a/show/688384660
# 623 https://krisha.kz/a/show/688158804
# 624 https://krisha.kz/a/show/687397166
# 625 https://krisha.kz/a/show/688999405
# 626 https://krisha.kz/a/show/688999506
# 627 https://krisha.kz/a/show/688999958
# 628 https://krisha.kz/a/show/688631136
# 629 https://krisha.kz/a/show/688165634
# 630 https://krisha.kz/a/show/688996331
# 631 https://krisha.kz/a/show/677396267
# 632 https://krisha.kz/a/show/688665809
# 633 https://krisha.kz/a/show/687893027
# 634 https://krisha.kz/a/show/688520416
# 635 https://krisha.kz/a/show/685676347
# 636 https://krisha.kz/a/show/685913375
# 637 https://krisha.kz/a/show/688837041
# 638 https://krisha.kz/a/show/688819727
# 639 https://krisha.kz/a/show/688867909
# 640 https://krisha.kz/a/show/688867057
# 641 https://krisha.kz/a/show/687022679
# 642 https://krisha.kz/a/show/684376923
# 643 https://krisha.kz/a/show/687594480
# 644 https://krisha.kz/a/show/678678158
# 645 https://krisha.kz/a/show/686704126
# 646 https://krisha.kz/a/show/686657827
# 647 https://krisha.kz/a/show/688352140
# 648 https://krisha.kz/a/show/688629102
# 649 https://krisha.kz/a/show/688682407
# 650 https://krisha.kz/a/show/687038052
# 651 https://krisha.kz/a/show/688890903
# 652 https://krisha.kz/a/show/687400199
# 653 https://krisha.kz/a/show/682122708
# 654 https://krisha.kz/a/show/687980104
# 655 https://krisha.kz/a/show/687612054
# 656 https://krisha.kz/a/show/686507260
# 657 https://krisha.kz/a/show/688932242
# 658 https://krisha.kz/a/show/688931446
# 659 https://krisha.kz/a/show/688773919
# 660 https://krisha.kz/a/show/684156230
# 661 https://krisha.kz/a/show/686470665
# 662 https://krisha.kz/a/show/688318143
# 663 https://krisha.kz/a/show/688859924
# 664 https://krisha.kz/a/show/687775323
# 665 https://krisha.kz/a/show/688954150
# 666 https://krisha.kz/a/show/678568312
# 667 https://krisha.kz/a/show/687926960
# 668 https://krisha.kz/a/show/687282978
# 669 https://krisha.kz/a/show/686157706
# 670 https://krisha.kz/a/show/687902877
# 671 https://krisha.kz/a/show/688973986
# 672 https://krisha.kz/a/show/688794801
# 673 https://krisha.kz/a/show/688956921
# 674 https://krisha.kz/a/show/688636976
# 675 https://krisha.kz/a/show/677841417
# 676 https://krisha.kz/a/show/684554950
# 677 https://krisha.kz/a/show/688446359
# 678 https://krisha.kz/a/show/688602834
# 679 https://krisha.kz/a/show/687913458
# 680 https://krisha.kz/a/show/688951561
# 681 https://krisha.kz/a/show/679716837
# 682 https://krisha.kz/a/show/688146322
# 683 https://krisha.kz/a/show/688975217
# 684 https://krisha.kz/a/show/688981569
# 685 https://krisha.kz/a/show/688865571
# 686 https://krisha.kz/a/show/688862200
# 687 https://krisha.kz/a/show/682092655
# 688 https://krisha.kz/a/show/688985669
# 689 https://krisha.kz/a/show/673661870
# 690 https://krisha.kz/a/show/688327672
# 691 https://krisha.kz/a/show/688983913
# 692 https://krisha.kz/a/show/684139862
# 693 https://krisha.kz/a/show/688901545
# 694 https://krisha.kz/a/show/687975663
# 695 https://krisha.kz/a/show/688671630
# 696 https://krisha.kz/a/show/688938984
# 697 https://krisha.kz/a/show/688144453
# 698 https://krisha.kz/a/show/683540589
# 699 https://krisha.kz/a/show/685855837
# 700 https://krisha.kz/a/show/688497689
# 701 https://krisha.kz/a/show/688603086
# 702 https://krisha.kz/a/show/689001438
# 703 https://krisha.kz/a/show/689001576
# 704 https://krisha.kz/a/show/684495993
# 705 https://krisha.kz/a/show/688978557
# 706 https://krisha.kz/a/show/687313718
# 707 https://krisha.kz/a/show/688983338
# 708 https://krisha.kz/a/show/683745831
# 709 https://krisha.kz/a/show/686391076
# 710 https://krisha.kz/a/show/688841209
# 711 https://krisha.kz/a/show/683711384
# 712 https://krisha.kz/a/show/672214660
# 713 https://krisha.kz/a/show/687766730
# 714 https://krisha.kz/a/show/687760603
# 715 https://krisha.kz/a/show/688891602
# 716 https://krisha.kz/a/show/687408909
# 717 https://krisha.kz/a/show/688379910
# 718 https://krisha.kz/a/show/688961041
# 719 https://krisha.kz/a/show/688165555
# 720 https://krisha.kz/a/show/687766652
# 721 https://krisha.kz/a/show/688834126
# 722 https://krisha.kz/a/show/687678990
# 723 https://krisha.kz/a/show/687154284
# 724 https://krisha.kz/a/show/674720232
# 725 https://krisha.kz/a/show/682427967
# 726 https://krisha.kz/a/show/688656134
# 727 https://krisha.kz/a/show/688949728
# 728 https://krisha.kz/a/show/685019515
# 729 https://krisha.kz/a/show/688870458
# 730 https://krisha.kz/a/show/688865327
# 731 https://krisha.kz/a/show/687161233
# 732 https://krisha.kz/a/show/688891394
# 733 https://krisha.kz/a/show/688890308
# 734 https://krisha.kz/a/show/688193931
# 735 https://krisha.kz/a/show/687585257
# 736 https://krisha.kz/a/show/688777933
# 737 https://krisha.kz/a/show/688957790
# 738 https://krisha.kz/a/show/687159357
# 739 https://krisha.kz/a/show/688980210
# 740 https://krisha.kz/a/show/688490148
# 741 https://krisha.kz/a/show/688768652
# 742 https://krisha.kz/a/show/688954877
# 743 https://krisha.kz/a/show/688455423
# 744 https://krisha.kz/a/show/682508280
# 745 https://krisha.kz/a/show/688981277
# 746 https://krisha.kz/a/show/688982840
# 747 https://krisha.kz/a/show/686949444
# 748 https://krisha.kz/a/show/688717665
# 749 https://krisha.kz/a/show/688840310
# 750 https://krisha.kz/a/show/688700539
# 751 https://krisha.kz/a/show/688872171
# 752 https://krisha.kz/a/show/688858160
# 753 https://krisha.kz/a/show/688841936
# 754 https://krisha.kz/a/show/688945890
# 755 https://krisha.kz/a/show/688482880
# 756 https://krisha.kz/a/show/687497122
# 757 https://krisha.kz/a/show/688752090
# 758 https://krisha.kz/a/show/688957662
# 759 https://krisha.kz/a/show/688942621
# 760 https://krisha.kz/a/show/686110779
# 761 https://krisha.kz/a/show/682726369
# 762 https://krisha.kz/a/show/684756033
# 763 https://krisha.kz/a/show/688654822
# 764 https://krisha.kz/a/show/688761297
# 765 https://krisha.kz/a/show/688335876
# 766 https://krisha.kz/a/show/688974516
# 767 https://krisha.kz/a/show/688645982
# 768 https://krisha.kz/a/show/687329705
# 769 https://krisha.kz/a/show/683214322
# 770 https://krisha.kz/a/show/688869223
# 771 https://krisha.kz/a/show/688869502
# 772 https://krisha.kz/a/show/688910543
# 773 https://krisha.kz/a/show/688838474
# 774 https://krisha.kz/a/show/688934934
# 775 https://krisha.kz/a/show/688099107
# 776 https://krisha.kz/a/show/682165504
# 777 https://krisha.kz/a/show/688916795
# 778 https://krisha.kz/a/show/687091294
# 779 https://krisha.kz/a/show/688962242
# 780 https://krisha.kz/a/show/688800252
# 781 https://krisha.kz/a/show/688237016
# 782 https://krisha.kz/a/show/688962210
# 783 https://krisha.kz/a/show/688312188
# 784 https://krisha.kz/a/show/688033779
# 785 https://krisha.kz/a/show/686782440
# 786 https://krisha.kz/a/show/688984372
# 787 https://krisha.kz/a/show/688677819
# 788 https://krisha.kz/a/show/686355091
# 789 https://krisha.kz/a/show/687933994
# 790 https://krisha.kz/a/show/688540831
# 791 https://krisha.kz/a/show/679228160
# 792 https://krisha.kz/a/show/680003596
# 793 https://krisha.kz/a/show/683538282
# 794 https://krisha.kz/a/show/678598163
# 795 https://krisha.kz/a/show/683564804
# 796 https://krisha.kz/a/show/680867783
# 797 https://krisha.kz/a/show/681762269
# 798 https://krisha.kz/a/show/687639745
# 799 https://krisha.kz/a/show/688280816
# 800 https://krisha.kz/a/show/688285763
# 801 https://krisha.kz/a/show/688047543
# 802 https://krisha.kz/a/show/688989071
# 803 https://krisha.kz/a/show/688875438
# 804 https://krisha.kz/a/show/684899863
# 805 https://krisha.kz/a/show/688283186
# 806 https://krisha.kz/a/show/688915767
# 807 https://krisha.kz/a/show/687532910
# 808 https://krisha.kz/a/show/688584145
# 809 https://krisha.kz/a/show/671121026
# 810 https://krisha.kz/a/show/686868564
# 811 https://krisha.kz/a/show/688090651
# 812 https://krisha.kz/a/show/670678502
# 813 https://krisha.kz/a/show/685877651
# 814 https://krisha.kz/a/show/681591895
# 815 https://krisha.kz/a/show/688699925
# 816 https://krisha.kz/a/show/688518866
# 817 https://krisha.kz/a/show/688173195
# 818 https://krisha.kz/a/show/688563622
# 819 https://krisha.kz/a/show/688858435
# 820 https://krisha.kz/a/show/688695707
# 821 https://krisha.kz/a/show/688854818
# 822 https://krisha.kz/a/show/688106595
# 823 https://krisha.kz/a/show/688879305
# 824 https://krisha.kz/a/show/688510528
# 825 https://krisha.kz/a/show/688623807
# 826 https://krisha.kz/a/show/681502304
# 827 https://krisha.kz/a/show/685093237
# 828 https://krisha.kz/a/show/688710055
# 829 https://krisha.kz/a/show/688309089
# 830 https://krisha.kz/a/show/688883491
# 831 https://krisha.kz/a/show/684868618
# 832 https://krisha.kz/a/show/679670142
# 833 https://krisha.kz/a/show/51961631
# 834 https://krisha.kz/a/show/688932445
# 835 https://krisha.kz/a/show/688793166
# 836 https://krisha.kz/a/show/688915567
# 837 https://krisha.kz/a/show/668046684
# 838 https://krisha.kz/a/show/688806175
# 839 https://krisha.kz/a/show/686780442
# 840 https://krisha.kz/a/show/688198234
# 841 https://krisha.kz/a/show/688956848
# 842 https://krisha.kz/a/show/688748171
# 843 https://krisha.kz/a/show/688924773
# 844 https://krisha.kz/a/show/686962578
# 845 https://krisha.kz/a/show/686747737
# 846 https://krisha.kz/a/show/688971633
# 847 https://krisha.kz/a/show/688971639
# 848 https://krisha.kz/a/show/688778441
# 849 https://krisha.kz/a/show/688977042
# 850 https://krisha.kz/a/show/682513500
# 851 https://krisha.kz/a/show/688656727
# 852 https://krisha.kz/a/show/688770065
# 853 https://krisha.kz/a/show/688996230
# 854 https://krisha.kz/a/show/686179396
# 855 https://krisha.kz/a/show/688317994
# 856 https://krisha.kz/a/show/688267383
# 857 https://krisha.kz/a/show/677798193
# 858 https://krisha.kz/a/show/688965733
# 859 https://krisha.kz/a/show/688546916
# 860 https://krisha.kz/a/show/688728713
# 861 https://krisha.kz/a/show/686985790
# 862 https://krisha.kz/a/show/688644951
# 863 https://krisha.kz/a/show/688844626
# 864 https://krisha.kz/a/show/684104406
# 865 https://krisha.kz/a/show/688861484
# 866 https://krisha.kz/a/show/688684824
# 867 https://krisha.kz/a/show/680725157
# 868 https://krisha.kz/a/show/688868340
# 869 https://krisha.kz/a/show/687934976
# 870 https://krisha.kz/a/show/676404218
# 871 https://krisha.kz/a/show/688880546
# 872 https://krisha.kz/a/show/688887586
# 873 https://krisha.kz/a/show/688890343
# 874 https://krisha.kz/a/show/687965382
# 875 https://krisha.kz/a/show/686926900
# 876 https://krisha.kz/a/show/688698261
# 877 https://krisha.kz/a/show/685162443
# 878 https://krisha.kz/a/show/688925148
# 879 https://krisha.kz/a/show/688159879
# 880 https://krisha.kz/a/show/688739424
# 881 https://krisha.kz/a/show/688735594
# 882 https://krisha.kz/a/show/682869808
# 883 https://krisha.kz/a/show/688529286
# 884 https://krisha.kz/a/show/688217710
# 885 https://krisha.kz/a/show/688421774
# 886 https://krisha.kz/a/show/685877429
# 887 https://krisha.kz/a/show/688432596
# 888 https://krisha.kz/a/show/686941472
# 889 https://krisha.kz/a/show/688967267
# 890 https://krisha.kz/a/show/683506540
# 891 https://krisha.kz/a/show/688782355
# 892 https://krisha.kz/a/show/688794954
# 893 https://krisha.kz/a/show/688953838
# 894 https://krisha.kz/a/show/681462813
# 895 https://krisha.kz/a/show/688949124
# 896 https://krisha.kz/a/show/688759374
# 897 https://krisha.kz/a/show/687655799
# 898 https://krisha.kz/a/show/688796835
# 899 https://krisha.kz/a/show/688840102
# 900 https://krisha.kz/a/show/688348031
# 901 https://krisha.kz/a/show/688985879
# 902 https://krisha.kz/a/show/687996260
# 903 https://krisha.kz/a/show/688869959
# 904 https://krisha.kz/a/show/688699816
# 905 https://krisha.kz/a/show/684754840
# 906 https://krisha.kz/a/show/686717690
# 907 https://krisha.kz/a/show/687289226
# 908 https://krisha.kz/a/show/688829600
# 909 https://krisha.kz/a/show/685226136
# 910 https://krisha.kz/a/show/688999862
# 911 https://krisha.kz/a/show/687441830
# 912 https://krisha.kz/a/show/687848064
# 913 https://krisha.kz/a/show/685365137
# 914 https://krisha.kz/a/show/688547004
# 915 https://krisha.kz/a/show/687789650
# 916 https://krisha.kz/a/show/688700213
# 917 https://krisha.kz/a/show/688130810
# 918 https://krisha.kz/a/show/688553757
# 919 https://krisha.kz/a/show/681370285
# 920 https://krisha.kz/a/show/684500816
# 921 https://krisha.kz/a/show/687816375
# 922 https://krisha.kz/a/show/672783960
# 923 https://krisha.kz/a/show/687999266
# 924 https://krisha.kz/a/show/686946736
# 925 https://krisha.kz/a/show/676990277
# 926 https://krisha.kz/a/show/687831005
# 927 https://krisha.kz/a/show/686343175
# 928 https://krisha.kz/a/show/688923759
# 929 https://krisha.kz/a/show/682884071
# 930 https://krisha.kz/a/show/687713943
# 931 https://krisha.kz/a/show/688939001
# 932 https://krisha.kz/a/show/687853559
# 933 https://krisha.kz/a/show/672895539
# 934 https://krisha.kz/a/show/688964862
# 935 https://krisha.kz/a/show/688946168
# 936 https://krisha.kz/a/show/688304866
# 937 https://krisha.kz/a/show/688782694
# 938 https://krisha.kz/a/show/688949805
# 939 https://krisha.kz/a/show/688793674
# 940 https://krisha.kz/a/show/687615429
# 941 https://krisha.kz/a/show/687336052
# 942 https://krisha.kz/a/show/9853518
# 943 https://krisha.kz/a/show/688977694
# 944 https://krisha.kz/a/show/688952416
# 945 https://krisha.kz/a/show/688336250
# 946 https://krisha.kz/a/show/688980956
# 947 https://krisha.kz/a/show/688981136
# 948 https://krisha.kz/a/show/688856935
# 949 https://krisha.kz/a/show/688752604
# 950 https://krisha.kz/a/show/688422398
# 951 https://krisha.kz/a/show/688610189
# 952 https://krisha.kz/a/show/688712074
# 953 https://krisha.kz/a/show/688950223
# 954 https://krisha.kz/a/show/687461428
# 955 https://krisha.kz/a/show/688567777
# 956 https://krisha.kz/a/show/688722639
# 957 https://krisha.kz/a/show/687818381
# 958 https://krisha.kz/a/show/686927786
# 959 https://krisha.kz/a/show/684354890
# 960 https://krisha.kz/a/show/683469646
# 961 https://krisha.kz/a/show/683470259
# 962 https://krisha.kz/a/show/688197363
# 963 https://krisha.kz/a/show/679584084
# 964 https://krisha.kz/a/show/688759511
# 965 https://krisha.kz/a/show/688793431
# 966 https://krisha.kz/a/show/688867507
# 967 https://krisha.kz/a/show/688678611
# 968 https://krisha.kz/a/show/684681672
# 969 https://krisha.kz/a/show/684896356
# 970 https://krisha.kz/a/show/688946363
# 971 https://krisha.kz/a/show/688883096
# 972 https://krisha.kz/a/show/687163426
# 973 https://krisha.kz/a/show/688840911
# 974 https://krisha.kz/a/show/688192623
# 975 https://krisha.kz/a/show/688704690
# 976 https://krisha.kz/a/show/684283324
# 977 https://krisha.kz/a/show/671659986
# 978 https://krisha.kz/a/show/678891409
# 979 https://krisha.kz/a/show/682855201
# 980 https://krisha.kz/a/show/687883265
# 981 https://krisha.kz/a/show/688839384
# 982 https://krisha.kz/a/show/677716836
# 983 https://krisha.kz/a/show/688337798
# 984 https://krisha.kz/a/show/669390923
# 985 https://krisha.kz/a/show/688145674
# 986 https://krisha.kz/a/show/685855110
# 987 https://krisha.kz/a/show/688881245
# 988 https://krisha.kz/a/show/687959941
# 989 https://krisha.kz/a/show/688888280
# 990 https://krisha.kz/a/show/688862224
# 991 https://krisha.kz/a/show/688298535
# 992 https://krisha.kz/a/show/680482720
# 993 https://krisha.kz/a/show/687029198
# 994 https://krisha.kz/a/show/688668125
# 995 https://krisha.kz/a/show/688310504
# 996 https://krisha.kz/a/show/687290774
# 997 https://krisha.kz/a/show/688950370
# 998 https://krisha.kz/a/show/688950918

# %%
df = pd.DataFrame(data, columns=["price", "room_count", "quadrature", "floor_text", "floor", "region_text", "region", "year",  
                                 "flat_toilet", "flat_balcony", "flat_balcony_g", 
                                 "flat_door", "inet_type", "flat_parking", "live_furniture", 
                                 "flat_flooring", "ceiling"])
df.to_csv("apartments_data_10000-11000.csv", index=False)
df
# Out:
#         price  room_count  quadrature floor_text  floor        region_text  \
# 0    54000000           2        89.0       8/12   0.67    Алмалинский р-н
# 1    54000000           2        62.0      12/12   1.00  Бостандыкский р-н
# 2    54000000           2        60.0      10/12   0.83  Бостандыкский р-н
# 3    54000000           2        63.0       5/12   0.42  Бостандыкский р-н
# 4    54000000           3        95.0        5/5   1.00      Медеуский р-н
# ..        ...         ...         ...        ...    ...                ...
# 994  50500000           4        80.0        5/5   1.00     Ауэзовский р-н
# 995  50500000           3        71.0        7/9   0.78    Алмалинский р-н
# 996  50500000           4        92.0        7/9   0.78     Ауэзовский р-н
# 997  50500000           4        95.0        7/9   0.78     Ауэзовский р-н
# 998  50500000           3        60.0      10/10   1.00  Бостандыкский р-н
#
#      region  year  flat_toilet                   flat_balcony flat_balcony_g  \
# 0     0.075  2015      no_info                        no_info        no_info
# 1     1.000  2019  совмещенный                         лоджия             да
# 2     1.000  2019      no_info                        no_info        no_info
# 3     1.000  2019   раздельный                        no_info        no_info
# 4     0.690  2021      no_info                         балкон             да
# ..      ...   ...          ...                            ...            ...
# 994   0.510  1982      no_info                балкон и лоджия             да
# 995   0.075  1996      no_info                         лоджия        no_info
# 996   0.510  1990      no_info                балкон и лоджия        no_info
# 997   0.510  1990      no_info  несколько балконов или лоджий             да
# 998   1.000  2016  совмещенный                        no_info        no_info
#
#          flat_door inet_type              flat_parking live_furniture  \
# 0          no_info   no_info                   no_info        no_info
# 1    металлическая    оптика                   паркинг      полностью
# 2          no_info   no_info                   паркинг      полностью
# 3          no_info   no_info                   паркинг        no_info
# 4    металлическая    оптика                   no_info       частично
# ..             ...       ...                       ...            ...
# 994  металлическая   no_info  рядом охраняемая стоянка       частично
# 995  металлическая   no_info  рядом охраняемая стоянка       частично
# 996  металлическая   no_info                   no_info       частично
# 997  металлическая   no_info                   no_info        no_info
# 998  металлическая      ADSL                   паркинг       частично
#
#     flat_flooring ceiling
# 0         no_info    None
# 1         ламинат       3
# 2         no_info       3
# 3         no_info       3
# 4         ламинат     2.7
# ..            ...     ...
# 994       ламинат     2.8
# 995       ламинат     2.7
# 996      линолеум    2.85
# 997       no_info    2.85
# 998       no_info       3
#
# [999 rows x 17 columns]

# %%
# data = []
# try:
#     print('https://krisha.kz/a/show/671314140')
#     apartment_data = get_apartment_data('https://krisha.kz/a/show/671314140')
#     data.append(apartment_data)
#     print(data)
# except Exception as e:
#     print(f"Failed to extract data from {link}. Error: {e}")
# Out:
# https://krisha.kz/a/show/671314140
# Медеуский р-н
# [{'price': 198092000, 'room_count': 5, 'quadrature': 175.31, 'floor_text': '1/1', 'floor': 1, 'region_text': 'Медеуский р-н', 'region': 0.69, 'year': 2023, 'ceiling': None, 'flat_priv_dorm': 0}]

# %%
df = pd.read_csv('links.csv')
df.shape
# Out:
# (59947, 1)

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (36320, 1)

# %%
df.to_csv('last_links_of_ap.csv', index=False)

# %%
df = pd.read_csv('apartments_data.csv')

# %%
m = round(df['ceiling'].mean(),2)
df['ceiling'].fillna(m, inplace=True)
df
# Out:
#       price  room_count  quadrature  floor                     region  year  \
# 0  53000000           2        71.0   0.71     Алматы, Ауэзовский р-н  2023
# 1  27800000           2        43.0   0.25     Алматы, Ауэзовский р-н  1962
# 2  46000000           3        80.7   0.46     Алматы, Жетысуский р-н  2022
# 3  47500000           2        49.0   0.89      Алматы, Медеуский р-н  1989
# 4  21500000           1        33.0   0.30     Алматы, Ауэзовский р-н  2023
# 5  26000000           2        64.0   1.00     Алматы, Жетысуский р-н  2008
# 6  38500000           1        40.3   1.00  Алматы, Бостандыкский р-н  2019
# 7  23500000           1        50.5   1.00  Алматы, Наурызбайский р-н  2022
# 8  26000000           2        49.0   0.50     Алматы, Алатауский р-н  2023
# 9  63000000           4       100.0   0.90  Алматы, Бостандыкский р-н  1988
#
#    flat_toilet flat_balcony flat_balcony_g      flat_door        inet_type  \
# 0      no_info      no_info        no_info        no_info          no_info
# 1      no_info      no_info        no_info  металлическая          no_info
# 2  совмещенный      no_info        no_info  металлическая          no_info
# 3      no_info       лоджия             да  металлическая  через TV кабель
# 4  совмещенный      no_info             да        no_info          no_info
# 5      no_info       балкон        no_info     деревянная             ADSL
# 6  совмещенный      no_info        no_info        no_info           оптика
# 7      no_info       балкон             да  металлическая          no_info
# 8      no_info      no_info        no_info        no_info          no_info
# 9      no_info       лоджия             да  металлическая           оптика
#
#                flat_parking live_furniture flat_flooring  ceiling
# 0                   паркинг        no_info       no_info     2.70
# 1  рядом охраняемая стоянка       частично       ламинат     2.77
# 2                   паркинг        no_info       no_info     2.75
# 3                   no_info      полностью       ламинат     2.80
# 4                   no_info        no_info       no_info     2.80
# 5                   no_info      полностью       ламинат     2.77
# 6                   паркинг      полностью       ламинат     2.85
# 7  рядом охраняемая стоянка       частично       ламинат     2.70
# 8                   no_info        no_info       no_info     2.77
# 9                   no_info        no_info      линолеум     2.77

# %%
one_hot_encoded = pd.get_dummies(df, columns=["flat_toilet", "flat_balcony", "flat_balcony_g", 
                                 "flat_door", "inet_type", "flat_parking", "live_furniture", 
                                 "flat_flooring"], 
                                 prefix=["flat_toilet", "flat_balcony", "flat_balcony_g", 
                                 "flat_door", "inet_type", "flat_parking", "live_furniture", 
                                 "flat_flooring"])
one_hot_encoded
# Out:
#       price  room_count  quadrature  floor                     region  year  \
# 0  53000000           2        71.0   0.71     Алматы, Ауэзовский р-н  2023
# 1  27800000           2        43.0   0.25     Алматы, Ауэзовский р-н  1962
# 2  46000000           3        80.7   0.46     Алматы, Жетысуский р-н  2022
# 3  47500000           2        49.0   0.89      Алматы, Медеуский р-н  1989
# 4  21500000           1        33.0   0.30     Алматы, Ауэзовский р-н  2023
# 5  26000000           2        64.0   1.00     Алматы, Жетысуский р-н  2008
# 6  38500000           1        40.3   1.00  Алматы, Бостандыкский р-н  2019
# 7  23500000           1        50.5   1.00  Алматы, Наурызбайский р-н  2022
# 8  26000000           2        49.0   0.50     Алматы, Алатауский р-н  2023
# 9  63000000           4       100.0   0.90  Алматы, Бостандыкский р-н  1988
#
#    ceiling  flat_toilet_no_info  flat_toilet_совмещенный  \
# 0     2.70                 True                    False
# 1     2.77                 True                    False
# 2     2.75                False                     True
# 3     2.80                 True                    False
# 4     2.80                False                     True
# 5     2.77                 True                    False
# 6     2.85                False                     True
# 7     2.70                 True                    False
# 8     2.77                 True                    False
# 9     2.77                 True                    False
#
#    flat_balcony_no_info  ...  inet_type_через TV кабель  flat_parking_no_info  \
# 0                  True  ...                      False                 False
# 1                  True  ...                      False                 False
# 2                  True  ...                      False                 False
# 3                 False  ...                       True                  True
# 4                  True  ...                      False                  True
# 5                 False  ...                      False                  True
# 6                  True  ...                      False                 False
# 7                 False  ...                      False                 False
# 8                  True  ...                      False                  True
# 9                 False  ...                      False                  True
#
#    flat_parking_паркинг  flat_parking_рядом охраняемая стоянка  \
# 0                  True                                  False
# 1                 False                                   True
# 2                  True                                  False
# 3                 False                                  False
# 4                 False                                  False
# 5                 False                                  False
# 6                  True                                  False
# 7                 False                                   True
# 8                 False                                  False
# 9                 False                                  False
#
#    live_furniture_no_info  live_furniture_полностью  live_furniture_частично  \
# 0                    True                     False                    False
# 1                   False                     False                     True
# 2                    True                     False                    False
# 3                   False                      True                    False
# 4                    True                     False                    False
# 5                   False                      True                    False
# 6                   False                      True                    False
# 7                   False                     False                     True
# 8                    True                     False                    False
# 9                    True                     False                    False
#
#    flat_flooring_no_info  flat_flooring_ламинат  flat_flooring_линолеум
# 0                   True                  False                   False
# 1                  False                   True                   False
# 2                   True                  False                   False
# 3                  False                   True                   False
# 4                   True                  False                   False
# 5                  False                   True                   False
# 6                  False                   True                   False
# 7                  False                   True                   False
# 8                   True                  False                   False
# 9                  False                  False                    True
#
# [10 rows x 30 columns]

# %%
# data = []
# for link in apartment_links[0:1]:
#     try:
#         apartment_data = get_apartment_data(link)
#         # data.append(apartment_data)
#     except Exception as e:
#         print(f"Failed to extract data from {link}. Error: {e}")

# %%
# for link in apartment_links[0:2]:
#     try: 
#         url = link
#         response = requests.get(url)
#         soup = BeautifulSoup(response.content, 'html.parser')
        
#         # Locate the section containing "О квартире"
#         # This step might vary based on the actual webpage structure; this is just a hypothetical approach
#         # For this example, let's assume "О квартире" is an h2 heading. Adjust as necessary.
#         section = soup.find('div', class_='offer__parameters')
#         # print(section.contents)
#         if len(section.contents)==1:
#             parent_div = None  # Get the parent div containing this heading and the parameters
#         else:
#             parent_div = section
        
#         if parent_div:
#             # Extract all the dt elements within this section to get all the data-name attributes
#             dt_elements = parent_div.find_all('dt')
            
#             # List to store the data-name attributes
#             data_names = []
            
#             for dt in dt_elements:
#                 data_name = dt.get('data-name')
#                 if data_name:
#                     data_names.append(data_name)
            
#             print(data_names)  # This will print all the data-name attributes
#         else:
#             print("Section 'О квартире' not found.")
#     except Exception as e:
#         print(f"Failed to extract data from {link}. Error: {e}")

# %%
# from bs4 import BeautifulSoup
# import requests

# # Fetch the page content
# url = 'https://krisha.kz/a/show/687771355'
# response = requests.get(url)
# soup = BeautifulSoup(response.content, 'html.parser')

# # Define the desired data-name value
# desired_data_name = "flat.door"  # or "flat.balcony_g" or any other value

# # Find the dt element with the specified data-name
# dt_element = soup.find('dt', {"data-name": desired_data_name})

# # If the dt element is found, extract the dd value
# if dt_element:
#     dd_element = dt_element.find_next_sibling("dd")
#     if dd_element:
#         print(dd_element.get_text().strip())
# else:
#     print(f"No element with data-name='{desired_data_name}' found.")
